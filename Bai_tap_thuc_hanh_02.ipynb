# %% [markdown]
# <a href="https://colab.research.google.com/github/plkimtuyen05-boop/ktuyen.github.com/blob/Kim-Tuy%E1%BB%81n/Bai_tap_thuc_hanh_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1

# %%
print("Whoever is happy will make others happy too");
print("--Anne Frank");
# Out:
# Whoever is happy will make others happy too
# --Anne Frank

# %% [markdown]
# Bài 2: Biểu thức tính toán

# %%
# Nhập dữ liệu
a = int(input("Moi ban nhap so a: "))
b = int(input("Moi ban nhap so b: "))
# Xử lý
kqCong = a + b
kqTru = a - b
kqNhan = a * b
kqChiaNguyen = a // b
kqDu= a % b
kqChiaThuc = a / b
# Xuất dữ liệu
print("Cac ket qua tinh toan: ")
print("%-5d + %5d = %5d"%(a, b, kqCong))
print("%-5d - %5d = %5d"%(a, b, kqTru))
print("%-5d * %5d = %5d"%(a, b, kqNhan))
print("%-5d / %5d = %5d"%(a, b, kqChiaNguyen))
print("%-5d / %5d = %5d"%(a, b, kqDu))
print("%-5d / %5d = %5.2f"%(a, b, kqChiaThuc))
# Out:
# Moi ban nhap so a: 2
# Moi ban nhap so b: 3
# Cac ket qua tinh toan:
# 2     +     3 =     5
# 2     -     3 =    -1
# 2     *     3 =     6
# 2     /     3 =     0
# 2     /     3 =     2
# 2     /     3 =  0.67

# %% [markdown]
# Bài 3: Biểu thức so sánh

# %%
# Nhập dữ liệu
a = float(input("Moi ban nhap so a: "))
b = float(input("Moi ban nhap so b: "))
# Xử lý
laNhoHon = (a < b)
laNhoHonBang = (a <= b)
laLonHon = (a > b)
laLonHonBang = (a >= b)
laBang = (a == b)
laKhacNhau = (a != b)
# Xuất dữ liệu
print("Ket qua so sanh hai so thuc %.2f va %.2f:"%(a, b))
print("%-8.2f <  %8.2f: %8s"%(a, b, laNhoHon))
print("%-8.2f <= %8.2f: %8s"%(a, b, laNhoHonBang))
print("%-8.2f >  %8.2f: %8s"%(a, b, laLonHon))
print("%-8.2f >= %8.2f: %8s"%(a, b, laLonHonBang))
print("%-8.2f == %8.2f: %8s"%(a, b, laBang))
print("%-8.2f != %8.2f: %8s"%(a, b, laKhacNhau))
# Out:
# Moi ban nhap so a: 4.2
# Moi ban nhap so b: 5.3
# Ket qua so sanh hai so thuc 4.20 va 5.30:
# 4.20     <      5.30:     True
# 4.20     <=     5.30:     True
# 4.20     >      5.30:    False
# 4.20     >=     5.30:    False
# 4.20     ==     5.30:    False
# 4.20     !=     5.30:     True

# %% [markdown]
# Bài 4. Tính giá trị hàm số

# %%
# Nạp thư viện
import math
# Nhập dữ liệu
x = float(input("Moi ban nhap vao gia tri cua bien so x: "))
# Xử lý
fx = x + math.pow(x, 5) / (1 * 2 * 3 * 4 * 5) + \
     math.sqrt(abs(x)) / math.pow(x, 3.0 / 2)
# Xuất dữ liệu
print("Gia tri cua ham so f(%.2f) = %.2f."%(x, fx))
# Out:
# Moi ban nhap vao gia tri cua bien so x: 2.3
# Gia tri cua ham so f(2.30) = 3.27.

# %% [markdown]
# Bài 5. Tổng chữ số

# %%
# Nhập dữ liệu
x = int(input("Moi ban nhap vao gia tri cua bien so x: "))
# Xử lý
a = x // 1000              # Hàng nghìn
b = (x // 100) % 10        # Hàng trăm
c = (x // 10) % 10         # Hàng chục
d = x % 10                 # Hàng đơn vị
#tính tổng
tong = a + b + c + d
# Xuất dữ liệu
print(f"{x} = {a} + {b} + {c} + {d} = {tong}")
# Out:
# Moi ban nhap vao gia tri cua bien so x: 1234
# 1234 = 1 + 2 + 3 + 4 = 10

# %% [markdown]
# BÀI TH 1: IN NHÃN

# %%
print("**************************");
print("* Truong: Dai Hoc UEH    *");
print("* Khoa: CNTT             *");
print("* Ho ten:                *");
print("**************************");
# Out:
# **************************
# * Truong: Dai Hoc UEH    *
# * Khoa: CNTT             *
# * Ho ten:                *
# **************************

# %% [markdown]
# BAI TH 2

# %%
# Nhập dữ liệu
a = int(input("Nhap ban kinh: "))
b = 3.14
# Xử lý
dt = math.pow(a, 2)*b
cv = 2*a*b
# Xuất dữ liệu
print("Cac ket qua tinh toan: ")
print("Dien tich S = %.2f" %(dt))   # %.2f để in số thực
print("Chu vi P = %.2f" %(cv))
# Out:
# Nhap ban kinh: 5
# Cac ket qua tinh toan:
# Dien tich S = 78.50
# Chu vi P = 31.40

# %% [markdown]
# Bài 3. Đổi sang giây DoiSangGiay.*

# %%
a = int(input("Nhap so gio: "))
b = int(input("Nhap so phut: "))
c = int(input("Nhap so giay: "))
# Xử lý
tong = a*3600 + b*60 + c
# Xuất dữ liệu
print(f"Tong so giay cua {a}:{b}:{c} la {tong}")   # %.2f để in số thực
# Out:
# Nhap so gio: 1
# Nhap so phut: 20
# Nhap so giay: 10
# Tong so giay cua 1:20:10 la 4810

# %% [markdown]
# Bài 4. Đổi sang giờ phút giây

# %%
# Nhập dữ liệu
x = int(input("Nhap vao tong so giay: "))
# Xử lý
a = x // 3600
b = (x % 3600) // 60
c = x % 60
#tính tổng
tong = a + b + c + d
# Xuất dữ liệu
print(f"{x} giay co dang {a}:{b}:{c}")
# Out:
# Nhap vao tong so giay: 4810
# 4810 giay co dang 1:20:10

# %% [markdown]
# Bài 5. Tính diện tích tam giác

# %%
a = float(input("Nhap do dai canh a: "))
b = float(input("Nhap do dai canh b: "))
c = float(input("Nhap do dai canh c: "))
# Xử lý
p = (a+b+c)/2
S= math.sqrt(abs(p*(p-a)*(p-b)*(p-c)))
# Xuất dữ liệu
print(f"Dien tich tam giac S = {S}")
# Out:
# Nhap do dai canh a: 2
# Nhap do dai canh b: 4
# Nhap do dai canh c: 3
# Dien tich tam giac S = 2.9047375096555625

# %% [markdown]
# Bài 6. Hàm Mũ

# %%
# Nhập dữ liệu
a = int(input("Nhap so thuc: "))
b = int(input("Nhap so mu: "))
#Xử lý
kq = math.pow(a, b)
# Xuất dữ liệu
print(f"Ket qua {a}^{b} = {kq}")
# Out:
# Nhap so thuc: 2
# Nhap so mu: 4
# Ket qua 2^4 = 16.0

# %% [markdown]
# Bài 7. Đảo số

# %%
# Nhập dữ liệu
x = int(input("Moi ban nhap vao gia tri cua bien so x: "))
# Xử lý
a = x // 1000              # Hàng nghìn
b = (x // 100) % 10        # Hàng trăm
c = (x // 10) % 10         # Hàng chục
d = x % 10                 # Hàng đơn vị
## Xuất dữ liệu
print(f"x = {x} -> {d}{c}{b}{a}")
# Out:
# Moi ban nhap vao gia tri cua bien so x: 1234
# x = 1234 -> 4321

# %% [markdown]
# Bài 8. Độ sang Radian

# %%
# Nhập dữ liệu
x = int(input("Nhap do: "))
# Xử lý
y = math.radians(x)
# Xuất dữ liệu
print(f"{x} do = {y}")
# Out:
# Nhap do: 90
# 90 do = 1.5707963267948966

# %% [markdown]
# Bài 9. Hàm số 1

# %%
# Nhập dữ liệu
x = float(input("Moi ban nhap vao gia tri cua bien so x: "))
# Xử lý
y1 = 4*(math.pow(x,2)+10*x*math.sqrt(x)+3*x+1)
# Xuất dữ liệu
print(f"y1 = {y1}")
# Out:
# Moi ban nhap vao gia tri cua bien so x: 4
# y1 = 436.0

# %%
# Nhập dữ liệu
x = float(input("Moi ban nhap vao gia tri cua bien so x: "))
# Xử lý
y2 = (math.sin(math.pi*math.pow(x,2))+math.sqrt(math.pow(x,2)+1)) / (math.pow((math.e),2*x)+ math.cos((math.pi/4)*x))
# Xuất dữ liệu
print(f"y2 = {y2}")
# Out:
# Moi ban nhap vao gia tri cua bien so x: 2
# y2 = 0.04095501360654834

# %% [markdown]
# Bai 10: Tinh khoang cach

# %%
import math
# Nhập tọa độ điểm A và B
x1 = float(input("Nhap x1: "))
y1 = float(input("Nhap y1: "))
x2 = float(input("Nhap x2: "))
y2 = float(input("Nhap y2: "))

# Tính khoảng cách
d = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# Xuất kết quả
print(f"Khoang cach giua A({x1}, {y1}) va B({x2}, {y2}) la {d:.2f}")
# Out:
# Nhap x1: 1
# Nhap y1: 2
# Nhap x2: 4
# Nhap y2: 6
# Khoang cach giua A(1.0, 2.0) va B(4.0, 6.0) la 5.00

# %% [markdown]
# CAU TRUC DIEU KIEN

# %% [markdown]
# Bai 1

# %%
# Input a, b, c
a = int(input())
b = int(input())
c = int(input())
# max a, b, c
def max_fn(a, b):
   return a if a > b else b
   pass # max_fn
vmax = max_fn(a, b)
vmax = max_fn(vmax, c)
# output
print("Max(%d, %d, %d) = %d"%(a, b, c, vmax))
# Out:
# 2
# 5
# 4
# Max(2, 5, 4) = 5

# %% [markdown]
# Bai 2: sap xep theo thu tu tang dan

# %%
# Input a, b, c
a = int(input())
b = int(input())
c = int(input())
#
numbers = [a, b, c]
numbers.sort()
print(numbers)
# Out:
# 5
# 3
# 8
# [3, 5, 8]

# %% [markdown]
# Bai 3: tim nghiem so thuc

# %%
# Input a, b with ax + b = 0
a = float(input())
b = int(input())
# Process
def solv1deg(a, b):
    """
    Solve Equation ax + b = 0
    """
    nsol, x = None, None
    if a == 0:
      if b == 0:
         nsol = -1
      else:
        nsol = 0
    else:
       nsol = 1
       x = -b / a
    return nsol, x
    pass # solv1deg
nsol, x = solv1deg(a, b)
# output
if nsol == -1:
   print("%.2fx + %.2f = 0: unlimited solutions"%(a, b))
elif nsol == 0:
   print("%.2fx + %.2f = 0: no solution"%(a, b))
else:
   print("%.2fx + %.2f = 0: x = %.2f"%(a, b, x))
# Out:
# 1
# 5
# 1.00x + 5.00 = 0: x = -5.00

# %% [markdown]
# Bai 4: Tim so ngay nam (dung re nhanh)

# %%
# Input
y = int(input())
# Process
def isleap(y):
    ans = False
    if y%400==0 or (y%4==0 and y%100 !=0):
       ans = True
    return ans
    pass # IsLeap
def daysyear(y):
    ans = 365
    if isleap(y):
       ans = 366
    return ans
    pass # daysyear
ans = daysyear(y)
# output
print("%d"%(ans))
# Out:
# 2003
# 365

# %% [markdown]
# Bai 5: tinh tona

# %%
# Nhập dữ liệu
a = float(input("Moi ban nhap so a: "))
b = float(input("Moi ban nhap so b: "))
op = input("Nhap phep toan (+, -, *, /): ")

# Xử lý theo phép toán
if op == "+":
    result = a + b
    print(f"{a} + {b} = {result}")
elif op == "-":
    result = a - b
    print(f"{a} - {b} = {result}")
elif op == "*":
    result = a * b
    print(f"{a} * {b} = {result}")
elif op == "/":
    if b == 0:
        print("Khong the chia cho 0!")
    else:
        result = a / b
        print(f"{a} / {b} = {result}")
else:
    print("Phep toan khong hop le!")
# Out:
# Moi ban nhap so a: 6
# Moi ban nhap so b: 4
# Nhap phep toan (+, -, *, /): *
# 6.0 * 4.0 = 24.0

# %% [markdown]
# Bai 6: tinh tien dien thu dong

# %%
# Nhập dữ liệu
a = int(input("Nhap so dien cu: "))
b = int(input("Nhap so dien moi: "))
kWh = b - a
if 0 < kWh < 100 :
   result = kWh * 1242
elif 100 < kWh <= 150 :
    result = 100 * 1242 + (kWh - 100) * 1304
elif 150 < kWh <= 200:
    result = 100 * 1242 + (150 - 100) * 1304 + (kWh - 150) * 1651
elif 200 < kWh <= 300:
    result = 100 * 1242 + (150 - 100) * 1304 + (200 - 150) * 1651 + (kWh - 200) * 1788
elif 300 < kWh <= 400:
    result = 100 * 1242 + (150 - 100) * 1304 + (200 - 150) * 1651 + (300 - 200) * 1788 + (kWh - 300) * 1912
else:
    result = 100 * 1242 + (150 - 100) * 1304 + (200 - 150) * 1651 + (300 - 200) * 1788 + (400 - 300) * 1912 + (kWh - 400) * 1962
tong = round(result * 1.10)
print(f"The amount to pay for 187 kWh consumed in the month is {tong} VNĐ")
# Out:
# Nhap so dien cu: 3
# Nhap so dien moi: 190
# The amount to pay for 187 kWh consumed in the month is 275536 VNĐ
