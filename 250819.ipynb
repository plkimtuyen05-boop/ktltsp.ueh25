# %% [markdown]
# <a href="https://colab.research.google.com/github/plkimtuyen05-boop/ktuyen.github.com/blob/main/250819.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# "

# %%
a=27
b=6
c=a%b;
print(a,b,c)
# Out:
# 27 6 3

# %%
print("Hello World")
display ("Hello, world")
# Out:
# Hello World
# 'Hello, world'

# %%
score=80
if score >=60:
print("pass")
pass # dummy
# Out:
#   File "/tmp/ipython-input-2612365787.py", line 3
#     print("pass")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
x=2
y=x + 1
print(f'x={x}, y={y}')
print ('x=%d, y=%d'%(x,y))
# Out:
# x=2, y=3
# x=2, y=3

# %%
from platform import pyhton python_version
print("Python Version:", python_version())
# Out:
#   File "/tmp/ipython-input-4021074239.py", line 1
#     from platform import pyhton python_version
#                                 ^
# SyntaxError: invalid syntax

# %%
#container
x = ["apple", "banana", "cherry"] #list : chứa các đối tượng khác
x[2]= 'hello'
print(x,x[2])
x = ("apple", "banana", "cherry") #tuple :chứa các đối tượng khác, readonly
#print x[2]= 'hello' = errol
print(x,x[2])
x = range(6) #range : r(6)=[0,5], r(min, max) : [min, max]
print(x, list(x)) #iterlator: hỉ cấp phát khi sử dụng kiểu iterator
x = {"name" : "Tom", "age" : 20} #dict
print(x, x['age'])
x = {"apple", "banana", "cherry"} #set
print(x)
x = frozenset({"apple", "banana", "cherry"})
#frozenset
print(x)
# Out:
# ['apple', 'banana', 'hello'] hello
# ('apple', 'banana', 'cherry') cherry
# range(0, 6) [0, 1, 2, 3, 4, 5]
# {'name': 'Tom', 'age': 20} 20
# {'banana', 'apple', 'cherry'}
# frozenset({'banana', 'apple', 'cherry'})

# %%
x = True #bool
print(x, type(x))
x = b"Hello" #bytes
print(x, type(x))

x = bytearray(5) #bytearray
print(x, type(x))

x = memoryview(bytes(5)) #memoryview
print(x, type(x))

x = None #NoneType
print(x, type(x))
# Out:
# True <class 'bool'>
# b'Hello' <class 'bytes'>
# bytearray(b'\x00\x00\x00\x00\x00') <class 'bytearray'>
# <memory at 0x79b513542ec0> <class 'memoryview'>
# None <class 'NoneType'>

# %%
x = str(3) # x will be '3'
print(x, type(x))

y = int(3.5) # y will be 3
print(y, type(y))

z = float(3) # z will be 3.0
print(z, type(z))
print (list(range(6)))
print(set([1,4,2,1,1,2,3,4]))
# Out:
# 3 <class 'str'>
# 3 <class 'int'>
# 3.0 <class 'float'>
# [0, 1, 2, 3, 4, 5]
# {1, 2, 3, 4}

# %%
x = 2 # int
y = 3.4 # float
z = 7j #complex
print(x, type(x))
print(y, type(y))
print(z, type(z))
# Out:
# 2 <class 'int'>
# 3.4 <class 'float'>
# 7j <class 'complex'>

# %%
Arithmetic Operators
Operator Name Example
  Addition 7 + 2 = 9
 Subtraction 7 - 2 = 5
* Multiplication 7 * 2 = 14
/ Division 7 / 2 = 3.5
// Floor division 7 // 2 = 3 (Quotient)
% Modulus 7 % 2 = 1 (Remainder)
** Exponentiation 7 ** 2 = 49
***
# Out:
#   File "<tokenize>", line 4
#     Subtraction 7 - 2 = 5
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
print('7 + 2 =', 7 + 2)
print('7 - 2 =', 7 - 2)
print('7 * 2 =', 7 * 2)
print('7 / 2 =', 7 / 2)
print('7 // 2 =', 7 // 2)
print('7 % 2 =', 7 % 2)
print('7 ** 2 =', 7 ** 2)
# Out:
# 7 + 2 = 9
# 7 - 2 = 5
# 7 * 2 = 14
# 7 / 2 = 3.5
# 7 // 2 = 3
# 7 % 2 = 1
# 7 ** 2 = 49

# %%
#boolean: true false
print(3>2)
print(3==2)
print(3<2)
# Out:
# True
# False
# False

# %%
#tính toán BMI
#input
height_cm = 170
weight_kg = 60
#process
height_m = height_cm/100
BMI = (weight_kg/(height_m**2))
print("Your BMI is: " + str(round(BMI,1)))
# Out:
# Your BMI is: 20.8

# %%
# How much is your $100 worth after 7 years?
fv = 100 * 1.1 ** 7
print('fv = ', round(fv, 2))
# output = 194.87
# Out:
# fv =  194.87

# %%
# Future Value
pv = 100
r = 0.1
n = 7
fv = pv * ((1 + (r)) ** n)
print(round(fv, 2))
# Out:
# 194.87

# %% [markdown]
# Data stucture

# %%
x = ["apple", "banana", "cherry"] #list
print(x, type(x))

x = ("apple", "banana", "cherry") #tuple
print(x, type(x))

x = {"name" : "Tom", "age" : 20, "class": "KTLT"} #dict
print(x, type(x))

x = {"apple", "banana", "cherry"} #set
print(x, type(x))
# Out:
# ['apple', 'banana', 'cherry'] <class 'list'>
# ('apple', 'banana', 'cherry') <class 'tuple'>
# {'name': 'Tom', 'age': 20, 'class': 'KTLT'} <class 'dict'>
# {'banana', 'apple', 'cherry'} <class 'set'>

# %%
x = [60, 70, 80, 90]
print(len(x))
print(x[0])
print(x[1])
print(x[-1])
print(x[1:3])
print(x[-2:-4:-1])
print(x[:-1], x[:], x[::-1])
# Out:
# 4
# 60
# 70
# 90
# [70, 80]
# [80, 70]
# [60, 70, 80] [60, 70, 80, 90] [90, 80, 70, 60]

# %%
a=[2,3,5]
b=[1,2]
a.extend(b)
a.append(10)
print(a)
# Out:
# [2, 3, 5, 1, 2, 10]

# %%
x = (10, 20, 30, 40, 50)
print(x[0])
print(x[1])
print(x[2])
print(x[-1])
# Out:
# 10
# 20
# 30
# 50

# %%
animals = {'cat', 'dog'}
print('cat' in animals)
print('fish' in animals)
animals.add('fish')
print(animals)
print('fish' in animals)
print(len(animals))
animals.add("cat")
print(len(animals))
animals.remove("cat")
print(len(animals))
# Out:
# True
# False
# {'fish', 'dog', 'cat'}
# True
# 3
# 3
# 2

# %%
a="hom nay la thu hai"
print(list(a))
print(len(a), list(a))
print(set(list(a)), len(set(list(a))))
# Out:
# ['h', 'o', 'm', ' ', 'n', 'a', 'y', ' ', 'l', 'a', ' ', 't', 'h', 'u', ' ', 'h', 'a', 'i']
# 18 ['h', 'o', 'm', ' ', 'n', 'a', 'y', ' ', 'l', 'a', ' ', 't', 'h', 'u', ' ', 'h', 'a', 'i']
# {'a', 'm', 'h', ' ', 'y', 'u', 'l', 'n', 'i', 'o', 't'} 11

# %%
k = { 'EN':'English'
,
'FR':'French' }
print(k['EN'])
# Out:
# English

# %%
a="hom nay la thu hai"
d_cnt = {}
for ci in list (a):
  if d_cnt.ge[ci] is None:
    d_cnt[ci] = 1
  else:
    d_cnt[ci] = d_cnt + 1
print(d_cnt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1600770754.py in <cell line: 0>()
#       2 d_cnt = {}
#       3 for ci in list (a):
# ----> 4   if d_cnt.ge[ci] is None:
#       5     d_cnt[ci] = 1
#       6   else:
#
# AttributeError: 'dict' object has no attribute 'ge'

# %%
fruits = ["apple", "banana", "cherry"] #lists []
print(fruits)
colors = ("red", "green", "blue") #tuples ()
print(colors)
animals = {'cat', 'dog'} #sets {}
print(animals)

person = {"name" : "Tom", "age" : 20} #dictionaries {}
print(person)
# Out:
# ['apple', 'banana', 'cherry']
# ('red', 'green', 'blue')
# {'dog', 'cat'}
# {'name': 'Tom', 'age': 20}
