# %% [markdown]
# # Buổi 3: Hien thi va phan tich du lieu voi Python

# %%
# !rm - r pydata-book
# !git clone https://github.com/wesm/pydata-book.git
# !ls pydata-book
# !sudo rm -r pydata-book/.git

# %%
# !sudo rm -r pydata-book/.git
# !git status
# !git add . -n
# !git add .
# !git commit -n "buoi03"
# !git push
# !git status
# !git push --force 
# !git reset HEAD-

# %% [markdown]
# # Kết thúc
