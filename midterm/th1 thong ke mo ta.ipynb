# %% [markdown]
# 1.1 THỐNG KÊ MÔ TẢ

# %% [markdown]
# BÀI TOÁN 1

# %% [markdown]
# NHIỆM VỤ 1

# %%
import numpy as np
import pandas as pd
from scipy import stats
# Load the .csv into a dataframe using read_csv
covid_data = pd.read_csv("covid-data.csv")
covid_data = covid_data[['Location','Day','total_case','new_case']]

# %%
# Take a quick look at the data
covid_data.head(5)
covid_data.dtypes
covid_data.shape
# Get the mean of the data
data_mean = np.mean(covid_data["new_case"])
# Get the median of the data
data_median = np.median(covid_data["new_case"])
# Get the mode of the data
data_mode = stats.mode(covid_data["new_case"])
# Obtain the variance of the data
data_variance = np.var(covid_data["new_case"])
# Obtain the standard deviation of the data
data_sd = np.std(covid_data["new_case"])
# Compute the maximum and minimum values of the data
data_max = np.max(covid_data["new_case"])
data_min = np.min(covid_data["new_case"])
# Obtain the 60th percentile of the data
data_percentile = np.percentile(covid_data["new_case"],60)
# Obtain the quartiles of the data
data_quartile = np.quantile(covid_data["new_case"],0.75)
# Get the IQR of the data
data_IQR = stats.iqr(covid_data["new_case"])

# %% [markdown]
# Nhiệm vụ 2:

# %%
import pandas as pd
marketing_data = pd.read_csv("marketing_campaign.csv")
marketing_data = marketing_data[['ID','Year_Birth', 'Education',
 'Marital_Status','Income','Kidhome', 'Teenhome',
 'Dt_Customer', 'Recency','NumStorePurchases',
 'NumWebVisitsMonth']]

# %%
marketing_data.head()
# Remove duplicates across the columns in our dataset:
marketing_data_duplicate = marketing_data.drop_duplicates()
# Delete a specified row at index value 1:
marketing_data.drop(labels=[1], axis=0)
# Delete a single column
marketing_data.drop(labels=['Year_Birth'], axis=1)
# Out:
#          ID   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0      5524  Graduation         Single  58138.0        0         0
# 1      2174  Graduation         Single  46344.0        1         1
# 2      4141  Graduation       Together  71613.0        0         0
# 3      6182  Graduation       Together  26646.0        1         0
# 4      5324         PhD        Married  58293.0        1         0
# ...     ...         ...            ...      ...      ...       ...
# 2235  10870  Graduation        Married  61223.0        0         1
# 2236   4001         PhD       Together  64014.0        2         1
# 2237   7270  Graduation       Divorced  56981.0        0         0
# 2238   8235      Master       Together  69245.0        0         1
# 2239   9405         PhD        Married  52869.0        1         1
#
#      Dt_Customer  Recency  NumStorePurchases  NumWebVisitsMonth
# 0     04-09-2012       58                  4                  7
# ...

# %%
# Replace the values in Teenhome with has teen and has no teen
marketing_data['Teenhome_replaced'] = marketing_data['Teenhome'].replace(
    {0: 'has no teen', 1: 'has teen', 2: 'has teen'}
)
# Fill NAs in the Income column
marketing_data['Income'] = marketing_data['Income'].fillna(0)
# Change the data type of the Income column from float to int
marketing_data['Income_changed'] = marketing_data['Income'].astype(int)

# %%
# Check for missing values using the isnull and sum methods
marketing_data.isnull().sum()
# Drop missing values using the dropna method
marketing_data_withoutna = marketing_data.dropna(how = 'any')
marketing_data_withoutna.shape
# Out:
# (2240, 13)

# %% [markdown]
# BÀI THỰC HÀNH 1

# %%
import numpy as np
import pandas as pd
from scipy import stats
# Load the .csv into a dataframe using read_csv
wine_data = pd.read_csv("winequality-red.csv")
wine_data = wine_data[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide',	'total sulfur dioxide','density','pH','sulphates','alcohol','quality'
]]

# %%
# Sử dụng hàm .describe() để thực hiện thống kê mô tả
descriptive_stats = wine_data.describe()
# In kết quả ra màn hình
print("Bảng thống kê mô tả bộ dữ liệu chất lượng rượu vang đỏ:")
print(descriptive_stats)
# Out:
# Bảng thống kê mô tả bộ dữ liệu chất lượng rượu vang đỏ:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# ...

# %% [markdown]
# 1.2 XỬ LÝ VÀ TRỰC QUAN HÓA DỮ LIỆU

# %% [markdown]
# BÀI TOÁN 1

# %% [markdown]
# NHIỆM VỤ 1

# %%
import numpy as np
import pandas as pd
from scipy import stats
# Load the .csv into a dataframe using read_csv
diabetes_data = pd.read_csv("diabetes.csv")
diabetes_data = diabetes_data[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome'
]]

# %%
# Sử dụng hàm .describe() để thực hiện thống kê mô tả
descriptive_stats = diabetes_data.describe()
# In kết quả ra màn hình
print("Bảng thống kê mô tả bộ dữ liệu về bệnh tiểu đường:")
print(descriptive_stats)
# Out:
# Bảng thống kê mô tả bộ dữ liệu về bệnh tiểu đường:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# ...

# %% [markdown]
# 1.2 XỬ LÝ VÀ TRE

# %%
import pandas as pd
houseprices_data = pd.read_csv("HousingPrices.csv")
houseprices_data = houseprices_data[['Zip', 'Price', 'Area', 'Room']]
# Create a PriceperSqm variable based on the Price and Area variables:
houseprices_data['PriceperSqm'] = houseprices_data['Price']/ houseprices_data['Area']

# %%
import pandas as pd
import matplotlib.pyplot as plt
houseprices_sorted = houseprices_data.sort_values('Price', ascending =
False)
houseprices_sorted.head()
# case 1: basic
plt.figure(figsize= (12,6))
x = houseprices_sorted['Zip'][0:10]
y = houseprices_sorted['Price'][0:10]
plt.bar(x,y)
plt.show()
# case 2: advanced 1
plt.figure(figsize= (12,6))
plt.bar(x,y)
plt.title('Top 10 Areas with the highest house prices', fontsize=15)
plt.xlabel('Zip code', fontsize = 12)
plt.xticks(fontsize=10)
plt.ylabel('House prices in millions', fontsize=12)
plt.yticks(fontsize=10)
plt.show()
# case 3: advanced 2
fig, ax = plt.subplots(figsize=(40,18))
x = houseprices_sorted['Zip'][0:10]
y = houseprices_sorted['Price'][0:10]
y1 = houseprices_sorted['PriceperSqm'][0:10]
plt.subplot(1,2,1)
plt.bar(x,y)
plt.xticks(fontsize=17)
plt.ylabel('House prices in millions', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 Areas with the highest house prices',
fontsize=25)
plt.subplot(1,2,2)
plt.bar(x,y1)
plt.xticks(fontsize=17)
plt.ylabel('House prices per sqm', fontsize=25)
plt.yticks(fontsize=20)
plt.title('Top 10 Areas with the highest house prices per sqm',
fontsize=25)
plt.savefig('case3 bt 1 nv1 1.2.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# case 1: basic
plt.figure(figsize= (12,6))
data = houseprices_sorted[0:10]
sns.barplot(data= data, x= 'Zip',y = 'Price')
# case 2: advanced 1
plt.figure(figsize= (12,6))
data = houseprices_sorted[0:10]
ax = sns.barplot(data= data, x= 'Zip',y = 'Price')
ax.set_xlabel('Zip code',fontsize = 10)
ax.set_ylabel('House prices in millions', fontsize = 10)
ax.set_title('Top 10 Areas with the highest house prices', fontsize= 20)
# case 3: view multiple perspectives at once
fig, ax = plt.subplots(1, 2,figsize=(40,18))
data = houseprices_sorted[0:10]
ax1 = sns.barplot(data= data, x= 'Zip',y = 'Price', ax = ax[0])
ax1.set_xlabel('Zip code')
ax1.set_ylabel('House prices in millions')
ax1.set_title('Top 10 Areas with the highest house prices')
ax2 = sns.barplot(data= data, x= 'Zip',y = 'PriceperSqm',
ax=ax[1])
ax2.set_xlabel('Zip code')
ax2.set_ylabel('House prices per sqm')
ax2.set_title('Top 10 Areas with the highest price per sqm')
fig.savefig('case3 bt 1 nv1 1.2 Seaborn.png')

# %% [markdown]
# BÀI THỰC HÀNH 1

# %%
import numpy as np
import pandas as pd
from scipy import stats
# Load the .csv into a dataframe using read_csv
wine_data = pd.read_csv("winequality-red.csv")
wine_data = wine_data[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide',	'total sulfur dioxide','density','pH','sulphates','alcohol','quality'
]]

# %%
#Biểu đồ điểm chất lượng
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.countplot(data=wine_data, x='quality', hue='quality', palette='viridis', legend=False)
plt.title('Phân bố số lượng rượu theo điểm chất lượng', fontsize=16)
plt.xlabel('Điểm chất lượng', fontsize=12)
plt.ylabel('Số lượng mẫu', fontsize=12)
plt.savefig('Bieu do diem chat luong bth 1.png')
plt.show()

# %%
#Nồng độ cồn theo chất lượng
plt.figure(figsize=(10, 6))
sns.barplot(data=wine_data, x='quality', y='alcohol', hue='quality', 
            palette='viridis', legend=False)
plt.title('Nồng độ cồn trung bình theo từng điểm chất lượng', fontsize=16)
plt.xlabel('Điểm chất lượng', fontsize=12)
plt.ylabel('Nồng độ cồn trung bình', fontsize=12)
plt.savefig('Bieu do nong do con theo chat luong bth 1.png')
plt.show()

# %%
#Phân bố axit dễ bay hơi theo chất lượng rượu
plt.figure(figsize=(12, 7))
sns.boxplot(data=wine_data, x='quality', y='volatile acidity', palette='coolwarm',
                hue='quality', legend=False) 
plt.title('Phân bố Axit dễ bay hơi theo Chất lượng rượu', fontsize=16)
plt.xlabel('Điểm chất lượng', fontsize=12)
plt.ylabel('Axit dễ bay hơi', fontsize=12)
plt.savefig('Phan bo axit theo chat luong ruou bth1.png')
plt.show()

# %%
#Phân bố tần suất nồng độ cồn
plt.figure(figsize=(10, 6))
sns.histplot(wine_data['alcohol'], kde=True, bins=20, color='purple')
plt.xlabel('Nồng độ cồn (%)', fontsize=12)
plt.ylabel('Tần suất', fontsize=12)
plt.savefig('Phan bo tan suat nong do con bth 1.png')
plt.show()

# %%
#Xu hướng Axit Citric trung bình theo Chất lượng rượu
plt.figure(figsize=(10, 6))
sns.lineplot(data=wine_data, x='quality', y='citric acid', marker='o', color='green')
plt.title('Xu hướng Axit Citric trung bình theo Chất lượng rượu', fontsize=16)
plt.xlabel('Điểm chất lượng', fontsize=12)
plt.ylabel('Axit Citric trung bình', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('Xu huong axit citric tb theo chat luong ruou bth 1.png')
plt.show()

# %% [markdown]
# BÀI THỰC HÀNH 2

# %% [markdown]
# DỮ LIỆU 1

# %%
import numpy as np
import pandas as pd
from scipy import stats
# Load the .csv into a dataframe using read_csv
diabetes_data = pd.read_csv("diabetes.csv")
diabetes_data = diabetes_data[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome'
]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns
# Tạo một figure chứa 2 biểu đồ con
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
# Biểu đồ cho Glucose
sns.histplot(data=diabetes_data, x='Glucose', hue='Outcome', kde=True, ax=axes[0], palette='coolwarm')
axes[0].set_title('Phân bố Nồng độ Glucose theo Kết quả', fontsize=14)
# Biểu đồ cho BMI
sns.histplot(data=diabetes_data, x='BMI', hue='Outcome', kde=True, ax=axes[1], palette='magma')
axes[1].set_title('Phân bố BMI theo Kết quả', fontsize=14)
plt.tight_layout()
plt.savefig('Glucose va BMI theo ket qua bth2.png')
plt.show()

# %%
# Đếm số lượng của mỗi Outcome
outcome_counts = diabetes_data['Outcome'].value_counts()
# Vẽ biểu đồ tròn
plt.pie(outcome_counts, labels=['Không bị bệnh (0)', 'Bị bệnh (1)'], 
            autopct='%1.1f%%', startangle=90, colors=['skyblue', 'salmon'])
    
plt.title('Tỉ lệ phần trăm kết quả Bệnh tiểu đường', fontsize=16)
plt.ylabel('') # Bỏ nhãn trục y
plt.savefig('% ket qua tieu duong bth2.png')
plt.show()

# %%
 # Lọc bỏ các hàng có BloodPressure = 0
data_filtered = diabetes_data[diabetes_data['Age'] > 0]
plt.figure(figsize=(10, 7))
sns.boxenplot(data=data_filtered, x='Outcome', y='Age', 
                  palette='pastel', hue='Outcome', legend=False)
plt.title('So sánh phân bố tuổi theo Kết quả', fontsize=16)
plt.xlabel('Kết quả (0: Không bị bệnh, 1: Bị bệnh)', fontsize=12)
plt.ylabel('Age', fontsize=12)
plt.xticks([0, 1], ['Không bị bệnh', 'Bị bệnh'])
plt.savefig('So sanh tuoi theo ket qua bth2.png')
plt.show()

# %% [markdown]
# DỮ LIỆU 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
online_retail_data = pd.read_csv("online_retail.csv",encoding='latin1')
online_retail_data = online_retail_data[['InvoiceNo', 'StockCode', 'Description', 'Quantity', 
                                         'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country']]

# %%
#Loại bỏ dữ liệu trùng lắp
online_retail_data.head()
# Remove duplicates across the columns in our dataset:
online_retail_data_duplicate = online_retail_data.drop_duplicates()
# Delete a specified row at index value 1:
online_retail_data.drop(labels=[1], axis=0)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#Xử lý dữ liệu thiếu
# Check for missing values using the isnull and sum methods
online_retail_data.isnull().sum()
# Drop missing values using the dropna method
online_retail_data_withoutna = online_retail_data.dropna(how = 'any')
online_retail_data_withoutna.shape
# Out:
# (406829, 8)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 # 1. Tải dữ liệu và sử dụng một tên biến nhất quán là 'df'
df = pd.read_csv("online_retail.csv", encoding='latin1')
# 2. Làm sạch dữ liệu (rất quan trọng với bộ dữ liệu này)
# Bỏ các dòng không có CustomerID
df.dropna(subset=['CustomerID'], inplace=True)
# Bỏ các giao dịch bị hủy (Quantity < 0)
df = df[df['Quantity'] > 0]
# Bỏ các mặt hàng có giá bằng 0
df = df[df['UnitPrice'] > 0]
# 3. Tạo biến mới có ý nghĩa
# Tạo cột 'TotalPrice' (Tổng giá trị) là biến số quan trọng
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
numeric_cols = ['Quantity', 'UnitPrice', 'TotalPrice']
df_numeric = df[numeric_cols]
# 5. Tính toán và vẽ ma trận tương quan
plt.figure(figsize=(8, 6))
correlation_matrix = df_numeric.corr()
# Vẽ biểu đồ nhiệt (heatmap)
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt='.2f')
plt.title('Ma trận tương quan giữa các thuộc tính số', fontsize=16)
plt.savefig('ma tran tuong quan bth2.png')
plt.show()

# %%
#Tính tổng doanh thu cho mỗi tháng
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['InvoiceMonth'] = df['InvoiceDate'].dt.month
monthly_revenue = df.groupby('InvoiceMonth')['TotalPrice'].sum()
plt.figure(figsize=(12, 7))
sns.lineplot(x=monthly_revenue.index, y=monthly_revenue.values, marker='o', color='royalblue')
plt.title('Tổng doanh thu theo từng tháng', fontsize=16)
plt.xlabel('Tháng', fontsize=12)
plt.ylabel('Tổng doanh thu', fontsize=12)
plt.xticks(range(1, 13)) # Đảm bảo trục x hiển thị đủ 12 tháng
plt.grid(True, linestyle='--', alpha=0.6)
plt.savefig('tong doanh thu theo tung thang bth2.png')
plt.show()

# %% [markdown]
# 1.3 PHÂN TÍCH ĐƠN BIẾN VÀ HAI BIẾN

# %% [markdown]
# BÀI TOÁN 1

# %% [markdown]
# NHIỆM VỤ 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
penguins_data = pd.read_csv("penguins_lter.csv")
penguins_data = penguins_data[['Species','Culmen Length (mm)']]

# %%
# case 1: basic
sns.histplot( data = penguins_data, x= penguins_data["Culmen Length (mm)"])
# case 2: advanced
plt.figure(figsize= (12,6))
ax = sns.histplot( data = penguins_data, x=
penguins_data["Culmen Length (mm)"])
ax.set_xlabel('Culmen Length in mm',fontsize = 15)
ax.set_ylabel('Count of records', fontsize = 15)
ax.set_title('Univariate analysis of Culmen Length',fontsize= 20)
plt.savefig('kq thuc hien case 2.png')

# %%
# case 1: basic
sns.countplot(data = penguins_data, x= penguins_data['Species'])
# case 2: advanced
plt.figure(figsize= (12,6))
ax = sns.countplot(data = penguins_data, x= penguins_data['Species'])
ax.set_xlabel('Penguin Species',fontsize = 20)
ax.set_ylabel('Count of records',fontsize = 15)
ax.set_title('Univariate analysis of Penguin Species', fontsize= 20)
ax.set_title('Univariate analysis of Culmen Length', fontsize= 20)
plt.savefig('kq thuc hien case 2-2.png')

# %%
penguins_group = penguins_data.groupby('Species').count()
penguins_group = penguins_group.reset_index()
# case 1: basic
plt.pie(penguins_group["Culmen Length (mm)"], labels =
 penguins_group['Species'])
plt.show()
# case 2: advanced
cols = ['g', 'b', 'r']
plt.pie(penguins_group["Culmen Length (mm)"], labels =
 penguins_group['Species'],colors = cols)
plt.title('Univariate Analysis of Species', fontsize=15)
plt.savefig('kq thuc hien case 2-3.png')
plt.show()

# %% [markdown]
# NHIỆM VỤ 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
houseprices_data = pd.read_csv("HousingPrices.csv")
houseprices_data = houseprices_data[['Zip','Price','Area','Room']]
# case 1: Create a boxplot using the boxplot method
sns.boxplot(data = houseprices_data, x= houseprices_data["Price"])
# case 2: advanced
plt.figure(figsize= (12,6))
ax = sns.boxplot(data = houseprices_data, x= houseprices_data["Price"])
ax.set_xlabel('House Prices in millions',fontsize = 15)
ax.set_title('Univariate analysis of House Prices', fontsize= 20)
plt.ticklabel_format(style='plain', axis='x')
plt.savefig('kq thuc hien case 2-4.png')

# %%
# case 1: basic
sns.violinplot(data = houseprices_data, x= houseprices_data["Price"])
# case 2: advanced
plt.figure(figsize= (12,6))
ax = sns.violinplot(data = houseprices_data, x=houseprices_data["Price"])
ax.set_xlabel('House Prices in millions',fontsize = 15)
ax.set_title('Univariate analysis of House Prices', fontsize= 20)
plt.ticklabel_format(style='plain', axis='x')
plt.savefig('kq thuc hien case 2-5.png')

# %%
houseprices_data.describe()
# Out:
#               Price        Area        Room
# count  9.200000e+02  924.000000  924.000000
# mean   6.220654e+05   95.952381    3.571429
# std    5.389942e+05   57.447436    1.592332
# min    1.750000e+05   21.000000    1.000000
# 25%    3.500000e+05   60.750000    3.000000
# 50%    4.670000e+05   83.000000    3.000000
# 75%    7.000000e+05  113.000000    4.000000
# max    5.950000e+06  623.000000   14.000000

# %% [markdown]
# BÀI TOÁN 2

# %% [markdown]
# NHIỆM VỤ 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
penguins_data = pd.read_csv("penguins_lter.csv")
penguins_data = penguins_data[['Species','Culmen Length (mm)', 'Body Mass (g)', 'Sex']]

# %%
# case 1: basic
sns.scatterplot(data = penguins_data, x= penguins_data["Culmen Length (mm)"],
 y= penguins_data['Body Mass (g)'])
# case 2: advanced
plt.figure(figsize= (12,6))
ax = sns.scatterplot(data = penguins_data,
 x= penguins_data["Culmen Length (mm)"],
 y= penguins_data['Body Mass (g)'])
ax.set_title('Bivariate analysis of Culmen Length and body mass', fontsize=
20)
plt.savefig('kq thuc hien case 2-6.png')

# %%
import numpy as np
pd.crosstab(index= penguins_data['Species'], columns= penguins_data['Sex'])
# Out:
# Sex                                        .  FEMALE  MALE
# Species
# Adelie Penguin (Pygoscelis adeliae)        0      73    73
# Chinstrap penguin (Pygoscelis antarctica)  0      34    34
# Gentoo penguin (Pygoscelis papua)          1      58    61

# %%
import numpy as np
pd.pivot_table(penguins_data, values='Culmen Length (mm)',
                        index='Species', aggfunc=np.mean)
# Out:
# /tmp/ipykernel_856/4246948306.py:2: FutureWarning: The provided callable <function mean at 0x7e6120722a20> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(penguins_data, values='Culmen Length (mm)',
#                                            Culmen Length (mm)
# Species
# Adelie Penguin (Pygoscelis adeliae)                 38.791391
# Chinstrap penguin (Pygoscelis antarctica)           48.833824
# Gentoo penguin (Pygoscelis papua)                   47.504878

# %%
import seaborn as sns
sns.pairplot( data = penguins_data)
plt.savefig('ket qua thuc hien case 2-7')

# %% [markdown]
# BÀI TOÁN 3

# %% [markdown]
# NHIỆM VỤ 1

# %%
# !pip install --upgrade joblib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install pandas-profiling[notebook]
# Out:
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install ydata-profiling[notebook]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 54.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 56.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 56.5 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 40.4 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 23.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 51.7 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 54.2 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.1
#     Uninstalling numpy-2.3.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  4/21 [numpy]
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport
marketing_data = pd.read_csv("marketing_campaign.csv")
# Create an Automated EDA report using the ProfileReport class in the ydata_profiling library. Use the to_file method to output the report to an HTML file
profile = ProfileReport(marketing_data)
profile.to_file("profile_output.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# 1️⃣ Xem kích thước và tổng quan dữ liệu
print("Kích thước dữ liệu:", marketing_data.shape)
print("\nSố lượng biến:", len(marketing_data.columns))
print("Số lượng quan sát:", len(marketing_data))

# 2️⃣ Kiểm tra giá trị thiếu
missing = marketing_data.isnull().sum()
print("\n--- Thống kê giá trị thiếu ---")
print(missing[missing > 0] if missing.sum() > 0 else "Không có giá trị thiếu.")
# 3️⃣ Thống kê mô tả cơ bản
print("\n--- Thống kê mô tả ---")
print(marketing_data.describe(include='all').T)
# Out:
# Kích thước dữ liệu: (2240, 11)
#
# Số lượng biến: 11
# Số lượng quan sát: 2240
#
# --- Thống kê giá trị thiếu ---
# Income    24
# dtype: int64
#
# --- Thống kê mô tả ---
#                     count unique         top  freq          mean  \
# ID                 2240.0    NaN         NaN   NaN   5592.159821
# Year_Birth         2240.0    NaN         NaN   NaN   1968.805804
# Education            2240      5  Graduation  1127           NaN
# Marital_Status       2240      8     Married   864           NaN
# Income             2216.0    NaN         NaN   NaN  52247.251354
# Kidhome            2240.0    NaN         NaN   NaN      0.444196
# Teenhome           2240.0    NaN         NaN   NaN       0.50625
# Dt_Customer          2240    663  31-08-2012    12           NaN
# Recency            2240.0    NaN         NaN   NaN     49.109375
# NumStorePurchases  2240.0    NaN         NaN   NaN      5.790179
# NumWebVisitsMonth  2240.0    NaN         NaN   NaN      5.316518
#
# ...

# %% [markdown]
# NHIỆM VỤ 2

# %%
# !pip install Flask
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [Flask]32m1/5 [itsdangerous]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install flask_compress
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 46.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [flask_compress]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 47.8 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [sweetviz]1/2 [sweetviz]
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !pip install -U joblib==1.3.2
# !pip install -U visions==0.7.4
# !pip install -U pandas-profiling==3.2.0
# Out:
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.3.2 which is incompatible.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#   Using cached visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.8.1
#     Uninstalling visions-0.8.1:
#       Successfully uninstalled visions-0.8.1
# ...

# %%
# !pip install numpy==1.26.4
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 52.7 MB/s eta 0:00:00:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.7.0 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import sweetviz as sv
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/sweetviz/graph.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
marketing_data = pd.read_csv("marketing_campaign.csv", sep=",")
report = sv.analyze(marketing_data)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
print(marketing_data.columns)
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'NumStorePurchases',
#        'NumWebVisitsMonth'],
#       dtype='object')

# %%
report.show_html(filepath="marketing_report.html", open_browser=False)
# Out:
# Report marketing_report.html was generated.

# %% [markdown]
# BÀI THỰC HÀNH 2

# %%
# !pip install autoviz
# Out:
# ...
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 57.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 53.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.1/30.1 MB 52.2 MB/s eta 0:00:00:00:01
# ...
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 25.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 41.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.0/802.0 kB 33.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 41.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.3/624.3 kB 29.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: joblib0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  6/24 [markdown]
# ...

# %%
import pandas as pd
from autoviz.AutoViz_Class import AutoViz_Class

marketing_data = pd.read_csv("marketing_campaign.csv", sep=",")
AV = AutoViz_Class()
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)

# %%
# Bước 1: đọc dữ liệu (chú ý dấu phân cách)
marketing_data = pd.read_csv("marketing_campaign.csv", sep=",")  # hoặc chỉnh sep nếu khác

# Bước 2: Khởi tạo AutoViz
AV = AutoViz_Class()
import os
os.makedirs("Reports/AutoViz_Plots", exist_ok=True)

# Bước 3: Gọi AutoViz để phân tích / vẽ biểu đồ
dft = AV.AutoViz(
    filename="bai tap thuc hanh 2",            # nếu bạn không dùng file trực tiếp, để trống
    sep=",",
    depVar="Income",              # ví dụ: nếu bạn muốn quan sát biến “Income” như target thì để depVar="Income"
    dfte=marketing_data,    # truyền DataFrame
    header=0,
    verbose=1,               # 0 = ít thông tin, 1 = hiển thị biểu đồ, 2 = lưu biểu đồ ra file mà không hiển thị
    lowess=False,           # nếu muốn dùng đường hồi quy LOWESS nếu dataset nhỏ
    chart_format="svg",     # hoặc "png", “html”, “bokeh”
    max_rows_analyzed=150000,
    max_cols_analyzed=30,
    save_plot_dir="Reports/AutoViz_Plots"       # nếu không muốn lưu vào thư mục riêng, hoặc bạn có thể chỉ định thư mục
)
# Out:
# Shape of your Data Set loaded: (2240, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  6
#     Number of String-Categorical Columns =  2
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     10 Predictors classified...
#         1 variable(s) removed since they were ID or low-information variables
#         List of variables removed: ['ID']
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 import os
#       3 plot_dir = "Midterm"
# ----> 4 plots = os.listdir(plot_dir)
#       6 for p in plots:
#       7     print(p)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Midterm'
